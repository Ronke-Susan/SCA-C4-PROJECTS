# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("C:\\Users\\RONKE\\Downloads\\output.csv")
df
# Out:
#         Year     Month        State              County  Rate
# 0       2015  February  Mississippi       Newton County   6.1
# 1       2015  February  Mississippi       Panola County   9.4
# 2       2015  February  Mississippi       Monroe County   7.9
# 3       2015  February  Mississippi        Hinds County   6.1
# 4       2015  February  Mississippi       Kemper County  10.6
# ...      ...       ...          ...                 ...   ...
# 885543  2009  November        Maine     Somerset County  10.5
# 885544  2009  November        Maine       Oxford County  10.5
# 885545  2009  November        Maine         Knox County   7.5
# 885546  2009  November        Maine  Piscataquis County  11.3
# 885547  2009  November        Maine    Aroostook County   9.0
#
# [885548 rows x 5 columns]

# %%
df.sample(50)
# Out:
#         Year      Month           State               County  Rate
# 521337  1999  September        Arkansas      Faulkner County   3.0
# 48952   2014    January        Michigan       Newaygo County   8.9
# 295723  1990   December         Arizona    Santa Cruz County  12.2
# 793865  2004   December    North Dakota      Renville County   3.3
# 295249  1990   December        Illinois         Piatt County   5.0
# 189237  2013       June        Michigan   Montmorency County  16.1
# 27475   2015   December  North Carolina          Wake County   4.2
# 768566  2004   February       Minnesota    Cottonwood County   5.0
# 800080  2005   February     Mississippi      Pontotoc County   5.6
# 461856  1997       July        Illinois      Woodford County   1.8
# 473774  1996      March        Michigan       Jackson County   5.2
# 610627  2003      March    South Dakota     Brookings County   2.9
# 123783  2011  September      California      Tuolumne County  13.5
# ...

# %%
#sorting df by year to view recent year 
df = df.sort_values(by=['Year','State'],ascending=False).reset_index(drop=True)

# %%
df
# Out:
#         Year     Month    State             County  Rate
# 0       2016  February  Wyoming  Sweetwater County   6.0
# 1       2016  February  Wyoming    Campbell County   6.4
# 2       2016  February  Wyoming    Converse County   5.8
# 3       2016  February  Wyoming    Sublette County   6.7
# 4       2016  February  Wyoming      Weston County   4.1
# ...      ...       ...      ...                ...   ...
# 885543  1990  November  Alabama     Baldwin County   5.3
# 885544  1990  November  Alabama  Tuscaloosa County   4.1
# 885545  1990  November  Alabama      Walker County   8.9
# 885546  1990  November  Alabama   Talladega County   8.3
# 885547  1990  November  Alabama    Cleburne County   8.2
#
# [885548 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# Year      0
# Month     0
# State     0
# County    0
# Rate      0
# dtype: int64

# %% [markdown]
# There are no missing values in the dataset

# %%
df.describe(include="all")
# Out:
#                  Year   Month   State             County           Rate
# count   885548.000000  885548  885548             885548  885548.000000
# unique            NaN      12      47               1752            NaN
# top               NaN   March   Texas  Washington County            NaN
# freq              NaN   74540   57658               8930            NaN
# mean      2003.000017     NaN     NaN                NaN       6.175010
# std          7.824893     NaN     NaN                NaN       3.112535
# min       1990.000000     NaN     NaN                NaN       0.000000
# 25%       1996.000000     NaN     NaN                NaN       4.000000
# 50%       2003.000000     NaN     NaN                NaN       5.500000
# 75%       2010.000000     NaN     NaN                NaN       7.700000
# max       2016.000000     NaN     NaN                NaN      58.400000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885548 entries, 0 to 885547
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Year    885548 non-null  int64
#  1   Month   885548 non-null  object
#  2   State   885548 non-null  object
#  3   County  885548 non-null  object
#  4   Rate    885548 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 33.8+ MB

# %%
sns.set(rc={'figure.figsize':(15,7)})
ax=sns.barplot(data=df,x='State',y='Rate')
for item in ax.get_xticklabels():#to give room for the x axis labels
    item.set_rotation(90)
    
ax.set_title("Unemployment Rate by State")
plt.savefig('unemployment_rate_by_state.png')

# %%
sns.set(rc={'figure.figsize':(15,7)})
ax=sns.barplot(data=df,x='Year',y='Rate')
for item in ax.get_xticklabels():#to give room for the x axis labels
    item.set_rotation(90)
    
ax.set_title("Unemployment Rate by Year")
plt.savefig('unemployment_rate_by_Year.png')

# %% [markdown]
# This statistic displays the unemployment rate in the U.S. from 1990 to 2016. In 1990, this rate stood at 6.0 percent. Unemployment rate stood at 5.1 percent in 2016.

# %%
# filter rows for year 2010 using  the boolean expression
year_2010 = df[df.Year.eq(2010)]
year_2010
# Out:
#         Year     Month    State             County  Rate
# 203700  2010  February  Wyoming  Sweetwater County   8.5
# 203701  2010  February  Wyoming    Campbell County   7.6
# 203702  2010  February  Wyoming    Converse County   6.4
# 203703  2010  February  Wyoming    Sublette County   7.6
# 203704  2010  February  Wyoming      Weston County   6.1
# ...      ...       ...      ...                ...   ...
# 238071  2010  November  Alabama     Baldwin County   9.6
# 238072  2010  November  Alabama  Tuscaloosa County   8.5
# 238073  2010  November  Alabama      Walker County  12.1
# 238074  2010  November  Alabama   Talladega County  12.5
# 238075  2010  November  Alabama    Cleburne County   9.8
#
# [34376 rows x 5 columns]

# %%
#checking for state with highest unemployment rate in 2010
sns.set(rc={'figure.figsize':(15,7)})
ax=sns.barplot(data=year_2010,x='State',y='Rate')
for item in ax.get_xticklabels():#to give room for the x axis labels
    item.set_rotation(90)
    
ax.set_title("Unemployment Rate by State for year 2010")
plt.savefig('unemployment_rate_by_State_for_year_2010.png')

# %%
#California = df[df.State.eq('California')]

# %%
California = year_2010[year_2010.State.eq('California')]

# %%
California
# Out:
#         Year     Month       State                  County  Rate
# 235612  2010  February  California         Humboldt County  11.3
# 235613  2010  February  California           Sonoma County  11.5
# 235614  2010  February  California  San Luis Obispo County  10.2
# 235615  2010  February  California            Glenn County  17.6
# 235616  2010  February  California           Nevada County  12.1
# ...      ...       ...         ...                     ...   ...
# 236187  2010  November  California            Butte County  13.7
# 236188  2010  November  California             Kern County  15.3
# 236189  2010  November  California             Napa County  10.7
# 236190  2010  November  California        Mendocino County  11.8
# 236191  2010  November  California           Plumas County  18.2
#
# [580 rows x 5 columns]

# %%
sns.set(rc={'figure.figsize':(15,7)})
ax=sns.barplot(data=California,x='County',y='Rate')
for item in ax.get_xticklabels():#to give room for the x axis labels
    item.set_rotation(90)
    
ax.set_title("Unemployment Rate by County in California in 2010")
#plt.savefig('unemployment_rate_by_Year.png')
# Out:
# Text(0.5, 1.0, 'Unemployment Rate by County in California in 2010')

# %%
sns.set(rc={'figure.figsize':(15,7)})
ax=sns.barplot(data=df,x='Month',y='Rate')
for item in ax.get_xticklabels():#to give room for the x axis labels
    item.set_rotation(90)
    
ax.set_title("Unemployment Rate by Month")
plt.savefig('unemployment_rate_by_Month.png')

# %% [markdown]
# why are people out of jobs in the first quater of the year(jan-march)?

# %%
year_2016 = df[df.Year.eq(2016)]
year_2016
# Out:
#        Year     Month    State             County  Rate
# 0      2016  February  Wyoming  Sweetwater County   6.0
# 1      2016  February  Wyoming    Campbell County   6.4
# 2      2016  February  Wyoming    Converse County   5.8
# 3      2016  February  Wyoming    Sublette County   6.7
# 4      2016  February  Wyoming      Weston County   4.1
# ...     ...       ...      ...                ...   ...
# 34301  2016  November  Alabama     Baldwin County   5.2
# 34302  2016  November  Alabama  Tuscaloosa County   5.2
# 34303  2016  November  Alabama      Walker County   6.8
# 34304  2016  November  Alabama   Talladega County   6.7
# 34305  2016  November  Alabama    Cleburne County   5.6
#
# [34306 rows x 5 columns]

# %%
#checking for state with highest unemployment rate in 2016
sns.set(rc={'figure.figsize':(15,7)})
ax=sns.barplot(data=year_2016,x='State',y='Rate')
for item in ax.get_xticklabels():#to give room for the x axis labels
    item.set_rotation(90)
    
ax.set_title("Unemployment Rate by State for year 2016")
plt.savefig('unemployment_rate_by_State_for_year_2016.png')
# Out:
# Text(0.5, 1.0, 'Unemployment Rate by State for year 2016')

# %%
sns.set(rc={'figure.figsize':(15,7)})
ax=sns.barplot(data=year_2016,x='Month',y='Rate')
for item in ax.get_xticklabels():#to give room for the x axis labels
    item.set_rotation(90)
    
ax.set_title("Unemployment Rate by Month for year 2016")
# Out:
# Text(0.5, 1.0, 'Unemployment Rate by Month for year 2016')

# %%
df['State'].value_counts()
# Out:
# Texas             57658
# Virginia          39900
# Missouri          37260
# Kentucky          36360
# Kansas            34020
# Illinois          33048
# North Carolina    32400
# Iowa              32076
# Tennessee         30780
# Nebraska          30132
# Indiana           29808
# Ohio              28512
# Minnesota         28188
# Mississippi       26568
# Oklahoma          24948
# Arkansas          24300
# Michigan          24236
# Wisconsin         23328
# Alabama           21708
# Pennsylvania      21708
# South Dakota      21384
# Colorado          20736
# New York          20088
# Montana           18144
# West Virginia     17820
# North Dakota      17172
# California        16878
# South Carolina    14904
# Idaho             14256
# Washington        12636
# Oregon            11664
# New Mexico        10692
# Utah               9396
# Maryland           7776
# Wyoming            7452
# New Jersey         6804
# Louisiana          6464
# Nevada             5508
# ...

# %%
County_rate=pd.DataFrame(df.set_index('County').Rate).reset_index(inplace=False)
County_rate.columns=['County','Rate']
County_rate

# %%
County_rate=County_rate.sort_values('Rate',ascending=False)
County_rate
